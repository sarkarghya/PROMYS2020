# %%
import random

def generate_polynomial(degree):
    """Originally degree, a, b chooses coefficients for a polynomial of the given degree, such that f(a) == b"""
    a = random.randint(0,1000) #use lower range to reduce computational load
    b = random.randint(0,10000)
    
    #to fit only one data point, we can choose arbitrary values for every coefficient except one, which we initially set to zero.
    coefficients = [0] + [random.randint(1, 10) for _ in range(degree-1)]

    #now calculate f(a). This will probably not be equal to b, initially.
    y = sum(coefficient * a**n for n, coefficient in enumerate(coefficients))

    #setting the final coefficient to their difference will cause f(a) to equal b.
    coefficients[0] = b - y

    return coefficients

#[-18, 7, 2] This corresponds to f(x) == 2*x^2 + 7*x - 18.


# coefficient a of exponent b
def co(a,b):
    li = []
    while len(li) != a:
        li.append(b)
    return li

import itertools
def flatum(l):
    merged = list(itertools.chain(*l))
    return(sum(l, []))

# makes polynomial without coefficients
def mp(k):
#    k = flatum(k)
    po = []
    i = 0
    while i < len(k):
        pr = k[i]
        ter = pow(n, pr)
        # change n to other varible if required
        po.append(ter)
        i += 1
    return sum(po) 

# with co function
def make_poly(r):
    return mp(flatum(r))



#make polynomial from just coefficients
def mpc(k):
    po = []
    for i in range(len(k)):
        cu = k[i]
        ter = cu*pow(n, i)
        # change n to other varible if required
        po.append(ter)
    return sum(po) 

#make random polynomial from just degree
def rand_poly(deg):
    return mpc(generate_polynomial(deg))

#computes mp fast no need of %p function
def mp_alpha(k):
#    k = flatum(k)
    po = []
    i = 0
    while i < len(k):
        pr = k[i]
        ter = pow(n, pr, p)
        # change n to other varible if required
        po.append(ter)
        i += 1
    return sum(po)

# %%
#Patrick salvage better find all
P = Primes()

for r in range(2, 26):
    actual = 1-1/float(e)
    result = []
    g = [pow(r,1), pow(r,2), pow(r,3)]
    for p_num in range(800, 1200):
        image = set()
        p = P.unrank(p_num)
        for n in range(0, p):
            image.add(mp_alpha(g) % p)
        m = (len(image)/p).n(100)
        result.append(m)
    mr = mean(result)
    ra = actual - mr
    print(r,mr,ra,g)
# Out:
# 2 0.39321294778967026388248730033 0.2389076110388874 [2, 4, 8]
# 3 0.45598648925733264046453393715 0.17613406957122502 [3, 9, 27]
# 4 0.30490487918217422943357956237 0.32721567964638343 [4, 16, 64]
# 5 0.52013066835201045011864005655 0.11198989047654717 [5, 25, 125]
# 6 0.27229830728815050382265402613 0.35982225154040715 [6, 36, 216]
# 7 0.54635042762956074321744399612 0.0857701311989969 [7, 49, 343]
# 8 0.27926556328031550553147612672 0.3528549955482422 [8, 64, 512]
# 9 0.42520960997139566191016507782 0.206910948857162 [9, 81, 729]
# 10 0.31944960453496512804821036675 0.31267095429359254 [10, 100, 1000]
# 11 0.57838919537994128724213498274 0.0537313634486164 [11, 121, 1331]
# 12 0.21000675485954930082718257771 0.4221138039690083 [12, 144, 1728]
# 13 0.58260306131654013125882985708 0.049517497512017505 [13, 169, 2197]
# 14 0.33765038046431135158955717190 0.2944701783642463 [14, 196, 2744]
# 15 0.37535034568971135242107008935 0.2567702131388463 [15, 225, 3375]
# 16 0.27046996723543712467758840323 0.3616505915931205 [16, 256, 4096]
# 17 0.59141128930240334843036996843 0.04070926952615428 [17, 289, 4913]
# 18 0.25512228148467891273326107139 0.37699827734387875 [18, 324, 5832]
# 19 0.59406192823517994759614163784 0.038058630593377774 [19, 361, 6859]
# 20 0.24789751257612803097586782349 0.38422304625242965 [20, 400, 8000]
# 21 0.39085699193125783869458293642 0.24126356689729983 [21, 441, 9261]
# 22 0.35862816672692978705847366090 0.2734923921016279 [22, 484, 10648]
# 23 0.60781097850953001795362690745 0.024309580319027635 [23, 529, 12167]
# 24 0.19203428511261471613925668825 0.44008627371594294 [24, 576, 13824]
# 25 0.51316824923149683036032908955 0.11895230959706082 [25, 625, 15625]

# %%
#Patrick salvage better find all
P = Primes()

for r in range(9, 50):
    putin = P.unrank(r)
    actual = 1-1/float(e)
    result = []
    g = [pow(putin,1), pow(putin,2), pow(putin,3)]
    for p_num in range(800, 1200):
        image = set()
        p = P.unrank(p_num)
        for n in range(0, p):
            image.add(mp_alpha(g) % p)
        m = (len(image)/p).n(100)
        result.append(m)
    mr = mean(result)
    ra = actual - mr
    print(putin,mr)
# Out:
# 29 0.60889594028345455007033284223
# 31 0.61483832716831943218342354089
# 37 0.60742462842780255241777570029
# 41 0.61618488905665247291907711402
# 43 0.61635012727949464713546037234
# 47 0.61907323983117342626506388336
# 53 0.62004931219744358675044244820
# 59 0.62155446026527471296227485257
# 61 0.61674815244409207792379221519
# 67 0.61834619221961019069395126949
# 71 0.62203847847998343740647525950
# 73 0.62489244425231100141803872437
# 79 0.61927252599759227491803389541
# 83 0.62533891636009795514276359114
# 89 0.62510435925564536058125451854
# 97 0.62765406953267956192927610316
# 101 0.62117759774708057617308893597
# 103 0.62671284140058504090253343975
# 107 0.62506393487631687418724949522
# 109 0.62646538867861913463369262084
# 113 0.62207916798948290092944202634
# 127 0.63125527010841667643437768102
# 131 0.62504718889790807329962832719
# 137 0.62342317475684929556709376341
# 139 0.62643569210213925262358549097
# 149 0.62563421922469007541661169078
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-8b1a9b1c64da> in <module>()
#      11         p = P.unrank(p_num)
#      12         for n in range(Integer(0), p):
# ---> 13             image.add(mp_alpha(g) % p)
#      14         m = (len(image)/p).n(Integer(100))
#      15         result.append(m)
#
# <ipython-input-8-f3f320d92fd6> in mp_alpha(k)
#      72     while i < len(k):
#      73         pr = k[i]
# ---> 74         ter = pow(n, pr, p)
#      75         # change n to other varible if required
#      76         po.append(ter)
#
# src/cysignals/signals.pyx in cysignals.signals.python_check_interrupt()
#
# KeyboardInterrupt:

# %%
#Finds all
P = Primes()
actual = 1-1/float(e)

for r in range(150, 151):    
    result = []
    g = [pow(r,1), pow(r,2), pow(r,3)]
    for p_num in range(800, 1300):
        image = set()
        p = P.unrank(p_num)
        for n in range(0, p):
            image.add(mp_alpha(g) % p)
        m = (len(image)/p).n(100)
        result.append(m)
    mr = mean(result)
    ra = actual - mr
    print(r,mr)
# Out:
# 26 0.36163817292299030078700448809
# 27 0.42319377272589209691303935020
# 28 0.26462911454677573255586780495
# 29 0.60730206615337700782024455157
# 30 0.22206092582359594414234089376
# 31 0.61522944040417390788956901358
# 32 0.27288207937525181903238048527
# 33 0.42108472660595922635809879430
# 34 0.36940108573826590040270172436
# 35 0.44811100520375651649771313543
# 36 0.20007224542896550450357122258
# 37 0.60855140064709743263456153219
# 38 0.37234857613562279548217631030
# 39 0.42312869255674525896540517917
# 40 0.22808741840610859692996226448
# 41 0.61576558198115973899842429357
# 42 0.23397993138265056408313230742
# 43 0.61839106379752662136803958224
# 44 0.28121615080643141881224117755
# 45 0.35194903435114011723711982544
# 46 0.37865720330325376549907480534
# 47 0.61812709421415186771904796951
# 48 0.19022103300549686912484156061
# 49 0.54194998025135451375712112190
# 50 0.31584825962755526036010872353
# 51 0.42905026107278385446568702316
# 52 0.28288418953078388568838869444
# 53 0.61852977983438869632232312450
# 54 0.25490443589375512736780589381
# 55 0.47206060974647659289312609473
# 56 0.24289208310169353309756342004
# 57 0.43367987339703305514983746653
# 58 0.37801122105480960053372266262
# 59 0.62243817368102405340599749995
# 60 0.17277655175744829088516132406
# 61 0.61824795517101899390996859022
# 62 0.38390628613268578376486156403
# 63 0.36866575476916509680348196683
# 64 0.27133549404007175056966033730
# 65 0.47725811760679199447883436419
# 66 0.25149990058575582469747253766
# 67 0.61972100755831414990616763953
# 68 0.28751516616464200381817650390
# 69 0.44421673455499443995545477366
# 70 0.27365475201625043920360645796
# 71 0.62133041441064750826081556099
# 72 0.18384535704060916988083550880
# 73 0.62387419172367968599187279225
# 74 0.38034755863899770665864379086
# 75 0.37159449588177474114237037945
# 76 0.29012276400734504433404966721
# 77 0.50178987832411317037174135641
# 78 0.25315139822650776894919363545
# 79 0.61909571207245103058457022743
# 80 0.22269428622600173077804252598
# 81 0.42107274277090553380094270039
# 82 0.38346180230916885825117490817
# 83 0.62513771332465990989151553411
# 84 0.18267957379014114300899714456
# 85 0.48732823104922542233220005339
# 86 0.38533236217844152030109619981
# 87 0.43931662840180734277399955159
# 88 0.25791315632585447580132847303
# 89 0.62556915686458456795480328544
# 90 0.20941288707748981441781363482
# 91 0.50390010693103089202502090183
# 92 0.29528054321133254217537009806
# 93 0.44561557647951289942298138777
# 94 0.38473572770125062759526661835
# 95 0.49142034089927274895431171621
# 96 0.18903790110721942127843423661
# 97 0.62721110163934823094982145542
# 98 0.33660137074450967049677134655
# 99 0.39316304018155378929520832718
# 100 0.24330369882372039427372584274
# 101 0.62246611673675499132447971477
# 102 0.25639065502501597335960401938
# 103 0.62646193210068560367065966958
# 104 0.25932774239249993235666013041
# 105 0.32247862494667741287278740752
# 106 0.38473921013431772785504340026
# 107 0.62379190539954127903168109436
# 108 0.19857200893239750463872402265
# 109 0.62487451059519489269672072414
# 110 0.29072553166010742152845288041
# 111 0.44405167949817190726249818595
# 112 0.23709372499480144299738440709
# 113 0.62386611778116117397324213933
# 114 0.25886821646827650359292582886
# 115 0.50387885451841009513598531997
# 116 0.29481304253304268672314766069
# 117 0.39535384296819254149853538297
# 118 0.38632941163225203497422670986
# 119 0.51380816648506319245921879194
# 120 0.15791058651327508435867244458
# 121 0.57392913660819382732992703692
# 122 0.38583143864107827324449206864
# 123 0.44678322778897058916558074752
# 124 0.29963202627385184538507790145
# 125 0.51266396064862187046015423790
# 126 0.22013189532850236766583100082
# 127 0.62998581791892518728940365575
# 128 0.27184418075343457162896611499
# 129 0.44919410286925524090507171188
# 130 0.29260690350348542309612028683
# 131 0.62632028456376832423754899783
# 132 0.19571524398828105287038809644
# 133 0.51535147196183118597131239929
# 134 0.38649190971212126977262369400
# 135 0.34818534127040418859158934887
# 136 0.26424538655452042956220365015
# 137 0.62324960510999920102888244802
# 138 0.26573163462585217697925407186
# 139 0.62608105052056014922678213429
# 140 0.21326510197987384343203710329
# 141 0.44717193720028768074186607164
# 142 0.38712979642606286272406211498
# 143 0.53384525854539067942021647946
# 144 0.17855931705325732558158273640
# 145 0.49990976308696042521160255983
# 146 0.38736860646424390247086950483
# 147 0.39247035206406357826447858722
# 148 0.29708964642381921697708554479
# 149 0.62530827038013870167119153373

# %%
#Finds all
P = Primes()
actual = 1-1/float(e)

for r in range(4, 5):    
    result = []
    g = [pow(r,1), pow(r,2), pow(r,3)]
    for p_num in range(800, 1200):
        image = set()
        p = P.unrank(p_num)
        for n in range(0, p):
            image.add(mp_alpha(g) % p)
        m = (len(image)/p).n(100)
        result.append(m)
    mr = mean(result)
    ra = actual - mr
    print(r,mr)
# Out:
# 4 0.30490487918217422943357956237

# %%
#calc
actual = 1-1/float(e)
r=actual^(7/4)

print(r)
# Out:
# 0.4481257005099324
